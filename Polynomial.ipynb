# %% [markdown]
# <a href="https://colab.research.google.com/github/sbborusu/530pm_Agentic_Ai_Batch_7thApril/blob/main/Polynomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/emp_sal.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  10 non-null     object
#  1   Level     10 non-null     int64
#  2   Salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
X = dataset.iloc[:,1:2].values # Drop irrelevant column Position
y = dataset.iloc[:,2].values

# %%
# Train/Test is not needed as the data is very less
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X,y)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y,color='red')
plt.plot(X,lin_reg.predict(X),color='blue')
plt.title('linear regression model (lienar regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
lin_model_pred = lin_reg.predict([[6.5]])
lin_model_pred
# Out:
# array([330378.78787879])

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=6) #With Degree = 2 or 3 or 4 there was difference between actual and predicted. For 5 and 6, the outputs
# were almost similar, so we can stop changing the degree.
X_poly = poly_reg.fit_transform(X)
X_poly
# Out:
# array([[1.00000e+00, 1.00000e+00, 1.00000e+00, 1.00000e+00, 1.00000e+00,
#         1.00000e+00, 1.00000e+00],
#        [1.00000e+00, 2.00000e+00, 4.00000e+00, 8.00000e+00, 1.60000e+01,
#         3.20000e+01, 6.40000e+01],
#        [1.00000e+00, 3.00000e+00, 9.00000e+00, 2.70000e+01, 8.10000e+01,
#         2.43000e+02, 7.29000e+02],
#        [1.00000e+00, 4.00000e+00, 1.60000e+01, 6.40000e+01, 2.56000e+02,
#         1.02400e+03, 4.09600e+03],
#        [1.00000e+00, 5.00000e+00, 2.50000e+01, 1.25000e+02, 6.25000e+02,
#         3.12500e+03, 1.56250e+04],
#        [1.00000e+00, 6.00000e+00, 3.60000e+01, 2.16000e+02, 1.29600e+03,
#         7.77600e+03, 4.66560e+04],
#        [1.00000e+00, 7.00000e+00, 4.90000e+01, 3.43000e+02, 2.40100e+03,
#         1.68070e+04, 1.17649e+05],
#        [1.00000e+00, 8.00000e+00, 6.40000e+01, 5.12000e+02, 4.09600e+03,
#         3.27680e+04, 2.62144e+05],
#        [1.00000e+00, 9.00000e+00, 8.10000e+01, 7.29000e+02, 6.56100e+03,
# ...

# %%
poly_reg.fit(X_poly,y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y,color='red')
plt.plot(X,lin_reg_2.predict(poly_reg.fit_transform(X)),color='blue')
plt.title('linear regression model (lienar regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %%
poly_model_pred = lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))
poly_model_pred
# Out:
# array([174192.81930595])
