# %% [markdown]
# <a href="https://colab.research.google.com/github/sbborusu/530pm_Agentic_Ai_Batch_7thApril/blob/main/ML_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv(r'/content/Salary_Data.csv')
dataset.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 612.0 bytes

# %%
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
print(x)
print(y)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]
# [ 39343  46205  37731  43525  39891  56642  60150  54445  64445  57189
#   63218  55794  56957  57081  61111  67938  66029  83088  81363  93940
#   91738  98273 101302 113812 109431 105582 116969 112635 122391 121872]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
print(x_train)
print('')
print(x_test)
print('')
print(y_train)
print('')
print(y_test)
# Out:
# [[ 9.6]
#  [ 4. ]
#  [ 5.3]
#  [ 7.9]
#  [ 2.9]
#  [ 5.1]
#  [ 3.2]
#  [ 4.5]
#  [ 8.2]
#  [ 6.8]
#  [ 1.3]
#  [10.5]
#  [ 3. ]
#  [ 2.2]
#  [ 5.9]
#  [ 6. ]
#  [ 3.7]
#  [ 3.2]
#  [ 9. ]
#  [ 2. ]
#  [ 1.1]
#  [ 7.1]
#  [ 4.9]
#  [ 4. ]]
#
# [[ 1.5]
#  [10.3]
#  [ 4.1]
#  [ 3.9]
#  [ 9.5]
#  [ 8.7]]
#
# [112635  55794  83088 101302  56642  66029  64445  61111 113812  91738
#   46205 121872  60150  39891  81363  93940  57189  54445 105582  43525
#   39343  98273  67938  56957]
#
# [ 37731 122391  57081  63218 116969 109431]

# %%
from sklearn.linear_model import LinearRegression #LinearRegression is Algorithm and linear_model is model
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
print(y_test) #Actual data
print(y_pred) #Predicted data
# Out:
# [ 37731 122391  57081  63218 116969 109431]
# [ 40748.96184072 122699.62295594  64961.65717022  63099.14214487
#  115249.56285456 107799.50275317]

# %%
plt.scatter(x_test, y_test, color = 'red') #Real salary
plt.plot(x_train, regressor.predict(x_train), color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
m_slope = regressor.coef_
print(m_slope)
# Out:
# [9312.57512673]

# %%
c_intercept = regressor.intercept_
print(c_intercept)
# Out:
# 26780.09915062818

# %%
y_12 = m_slope * 12 + c_intercept #predicting salary of 12 year experinced guy.
print(y_12)
# Out:
# [138531.00067138]

# %%
comparison = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(comparison)
# Out:
#    Actual      Predicted
# 0   37731   40748.961841
# 1  122391  122699.622956
# 2   57081   64961.657170
# 3   63218   63099.142145
# 4  116969  115249.562855
# 5  109431  107799.502753
