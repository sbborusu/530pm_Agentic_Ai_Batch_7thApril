# %% [markdown]
# <a href="https://colab.research.google.com/github/sbborusu/530pm_Agentic_Ai_Batch_7thApril/blob/main/Chi_Square_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Create the contingency table (observed table)
data = [[20, 30],   # Male: [Like, Dislike]
        [25, 25]]   # Female: [Like, Dislike]

# Create dataframe for clarity

df = pd.DataFrame(data, columns=['Like', 'Dislike'], index=['Male', 'Female'])
print(df)
# Out:
#         Like  Dislike
# Male      20       30
# Female    25       25

# %%
# Perform Chi-Square Test
chi2, p, dof, expected = chi2_contingency(df)

# %%
# Display results
print("Chi-square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-value:", p)
print("Expected Frequencies:\n", expected)
# Out:
# Chi-square Statistic: 0.6464646464646464
# Degrees of Freedom: 1
# P-value: 0.4213795037428696
# Expected Frequencies:
#  [[22.5 27.5]
#  [22.5 27.5]]
